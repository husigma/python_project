# %%
#Loading Libraries
import urllib
import urllib.request
from bs4 import BeautifulSoup

# %%
from Robinhood import Robinhood

# %%
help(Robinhood)
# Out:
# Help on class Robinhood in module Robinhood.Robinhood:
#
# class Robinhood(builtins.object)
#  |  Wrapper class for fetching/parsing Robinhood endpoints
#  |
#  |  Methods defined here:
#  |
#  |  GenerateDeviceToken(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  adjusted_equity_previous_close(self)
#  |      Wrapper for portfolios
#  |
#  |      Returns:
#  |          (float): `adjusted_equity_previous_close` value
#  |
#  |  adjusted_previous_close(self, stock='')
#  |      Get adjusted previous closing price for a stock
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (float): adjusted previous closing price
#  |
#  |  ask_price(self, stock='')
#  |      Get asking price for a stock
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (float): ask price
#  |
#  |  ask_size(self, stock='')
#  |      Get ask size for a stock
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (int): ask size
#  |
#  |  auth_method(self)
#  |
#  |  bid_price(self, stock='')
#  |      Get bid price for a stock
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (float): bid price
#  |
#  |  bid_size(self, stock='')
#  |      Get bid size for a stock
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (int): bid size
#  |
#  |  cancel_order(self, order_id)
#  |      Cancels specified order and returns the response (results from `orders` command).
#  |      If order cannot be cancelled, `None` is returned.
#  |      Args:
#  |          order_id (str or dict): Order ID string that is to be cancelled or open order dict returned from
#  |          order get.
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  dividends(self)
#  |      Wrapper for portfolios
#  |
#  |      Returns:
#  |          (:obj: `dict`): JSON dict from getting dividends
#  |
#  |  equity(self)
#  |      Wrapper for portfolios
#  |
#  |      Returns:
#  |          (float): `equity` value
#  |
#  |  equity_previous_close(self)
#  |      Wrapper for portfolios
#  |
#  |      Returns:
#  |          (float): `equity_previous_close` value
#  |
#  |  excess_margin(self)
#  |      Wrapper for portfolios
#  |
#  |      Returns:
#  |          (float): `excess_margin` value
#  |
#  |  extended_hours_equity(self)
#  |      Wrapper for portfolios
#  |
#  |      Returns:
#  |          (float): `extended_hours_equity` value
#  |
#  |  extended_hours_market_value(self)
#  |      Wrapper for portfolios
#  |
#  |      Returns:
#  |          (float): `extended_hours_market_value` value
#  |
#  |  fundamentals(self, stock='')
#  |      Wrapper for get_fundamentlals function
#  |
#  |  get_account(self)
#  |      Fetch account information
#  |
#  |      Returns:
#  |          (:obj:`dict`): `accounts` endpoint payload
#  |
#  |  get_fundamentals(self, stock='')
#  |      Find stock fundamentals data
#  |
#  |      Args:
#  |          (str): stock ticker
#  |
#  |      Returns:
#  |          (:obj:`dict`): contents of `fundamentals` endpoint
#  |
#  |  get_historical_quotes(self, stock, interval, span, bounds=<Bounds.REGULAR: 'regular'>)
#  |      Fetch historical data for stock
#  |
#  |      Note: valid interval/span configs
#  |          interval = 5minute | 10minute + span = day, week
#  |          interval = day + span = year
#  |          interval = week
#  |          TODO: NEEDS TESTS
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |          interval (str): resolution of data
#  |          span (str): length of data
#  |          bounds (:enum:`Bounds`, optional): 'extended' or 'regular' trading hours
#  |
#  |      Returns:
#  |          (:obj:`dict`) values returned from `historicals` endpoint
#  |
#  |  get_mfa_token(self, secret)
#  |
#  |  get_news(self, stock)
#  |      Fetch news endpoint
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (:obj:`dict`) values returned from `news` endpoint
#  |
#  |  get_option_market_data = wrapper(self, *args, **kwargs)
#  |
#  |  get_options(self, stock, expiration_dates, option_type)
#  |      Get a list (chain) of options contracts belonging to a particular stock
#  |
#  |      Args: stock ticker (str), list of expiration dates to filter on (YYYY-MM-DD), and whether or not its a 'put' or a 'call' option type (str).
#  |
#  |      Returns:
#  |          Options Contracts (List): a list (chain) of contracts for a given underlying equity instrument
#  |
#  |  get_popularity(self, stock='')
#  |      Get the number of robinhood users who own the given stock
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (int): number of users who own the stock
#  |
#  |  get_quote(self, stock='')
#  |      Wrapper for quote_data
#  |
#  |  get_quote_list(self, stock='', key='')
#  |      Returns multiple stock info and keys from quote_data (prompt if blank)
#  |
#  |      Args:
#  |          stock (str): stock ticker (or tickers separated by a comma)
#  |          , prompt if blank
#  |          key (str): key attributes that the function should return
#  |
#  |      Returns:
#  |          (:obj:`list`): Returns values from each stock or empty list
#  |                         if none of the stocks were valid
#  |
#  |  get_tickers_by_tag(self, tag=None)
#  |      Get a list of instruments belonging to a tag
#  |
#  |      Args: tag - Tags may include but are not limited to:
#  |          * top-movers
#  |          * etf
#  |          * 100-most-popular
#  |          * mutual-fund
#  |          * finance
#  |          * cap-weighted
#  |          * investment-trust-or-fund
#  |
#  |      Returns:
#  |          (List): a list of Ticker strings
#  |
#  |  get_url(self, url)
#  |      Flat wrapper for fetching URL directly
#  |
#  |  instrument(self, id)
#  |      Fetch instrument info
#  |
#  |      Args:
#  |          id (str): instrument id
#  |
#  |      Returns:
#  |          (:obj:`dict`): JSON dict of instrument
#  |
#  |  instruments(self, stock)
#  |      Fetch instruments endpoint
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (:obj:`dict`): JSON contents from `instruments` endpoint
#  |
#  |  investment_profile(self)
#  |      Fetch investment_profile
#  |
#  |  last_core_equity(self)
#  |      Wrapper for portfolios
#  |
#  |      Returns:
#  |          (float): `last_core_equity` value
#  |
#  |  last_core_market_value(self)
#  |      Wrapper for portfolios
#  |
#  |      Returns:
#  |          (float): `last_core_market_value` value
#  |
#  |  last_trade_price(self, stock='')
#  |      Get last trade price for a stock
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (float): last trade price
#  |
#  |  last_updated_at(self, stock='')
#  |      Get last update datetime
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (str): last update datetime
#  |
#  |  last_updated_at_datetime(self, stock='')
#  |      Get last updated datetime
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |          `self.last_updated_at` returns time as `str` in format: 'YYYY-MM-ddTHH:mm:ss:000Z'
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (datetime): last update datetime
#  |
#  |  login(self, username, password, qr_code=None)
#  |      Save and test login info for Robinhood accounts
#  |      Args:
#  |          username (str): username
#  |          password (str): password
#  |          qr_code (str): QR code that will be used to generate mfa_code (optional but recommended)
#  |          To get QR code, set up 2FA in Security, get Authentication App, and click "Can't Scan It?"
#  |      Returns:
#  |          (bool): received valid auth token
#  |
#  |  login_required(function)
#  |      Decorator function that prompts user for login if they are not logged in already. Can be applied to any function using the @ notation.
#  |
#  |  logout(self)
#  |      Logout from Robinhood
#  |
#  |      Returns:
#  |          (:obj:`requests.request`) result from logout endpoint
#  |
#  |  market_value(self)
#  |      Wrapper for portfolios
#  |
#  |      Returns:
#  |          (float): `market_value` value
#  |
#  |  order_history = wrapper(self, *args, **kwargs)
#  |
#  |  place_buy_order(self, instrument, quantity, ask_price=0.0)
#  |      Wrapper for placing buy orders
#  |
#  |      Args:
#  |          instrument (dict): the RH URL and symbol in dict for the instrument to be traded
#  |          quantity (int): quantity of stocks in order
#  |          ask_price (float): price for order (OPTIONAL! If not given, ask_price is automatic.)
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  place_limit_buy_order(self, instrument_URL=None, symbol=None, time_in_force=None, price=None, quantity=None)
#  |      Wrapper for placing limit buy orders
#  |
#  |      Notes:
#  |          If only one of the instrument_URL or symbol are passed as
#  |          arguments the other will be looked up automatically.
#  |
#  |      Args:
#  |          instrument_URL (str): The RH URL of the instrument
#  |          symbol (str): The ticker symbol of the instrument
#  |          time_in_force (str): 'GFD' or 'GTC' (day or until cancelled)
#  |          price (float): The max price you're willing to pay per share
#  |          quantity (int): Number of shares to buy
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  place_limit_sell_order(self, instrument_URL=None, symbol=None, time_in_force=None, price=None, quantity=None)
#  |      Wrapper for placing limit sell orders
#  |
#  |      Notes:
#  |          If only one of the instrument_URL or symbol are passed as
#  |          arguments the other will be looked up automatically.
#  |
#  |      Args:
#  |          instrument_URL (str): The RH URL of the instrument
#  |          symbol (str): The ticker symbol of the instrument
#  |          time_in_force (str): 'GFD' or 'GTC' (day or until cancelled)
#  |          price (float): The minimum price you're willing to get per share
#  |          quantity (int): Number of shares to sell
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  place_market_buy_order(self, instrument_URL=None, symbol=None, time_in_force=None, quantity=None)
#  |      Wrapper for placing market buy orders
#  |
#  |      Notes:
#  |          If only one of the instrument_URL or symbol are passed as
#  |          arguments the other will be looked up automatically.
#  |
#  |      Args:
#  |          instrument_URL (str): The RH URL of the instrument
#  |          symbol (str): The ticker symbol of the instrument
#  |          time_in_force (str): 'GFD' or 'GTC' (day or until cancelled)
#  |          quantity (int): Number of shares to buy
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  place_market_sell_order(self, instrument_URL=None, symbol=None, time_in_force=None, quantity=None)
#  |      Wrapper for placing market sell orders
#  |
#  |      Notes:
#  |          If only one of the instrument_URL or symbol are passed as
#  |          arguments the other will be looked up automatically.
#  |
#  |      Args:
#  |          instrument_URL (str): The RH URL of the instrument
#  |          symbol (str): The ticker symbol of the instrument
#  |          time_in_force (str): 'GFD' or 'GTC' (day or until cancelled)
#  |          quantity (int): Number of shares to sell
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  place_order(self, instrument, quantity=1, price=0.0, transaction=None, trigger='immediate', order='market', time_in_force='gfd')
#  |      Place an order with Robinhood
#  |
#  |      Args:
#  |          instrument (dict): the RH URL and symbol in dict for the instrument to be traded
#  |          quantity (int): quantity of stocks in order
#  |          bid_price (float): price for order
#  |          transaction (:enum:`Transaction`): BUY or SELL enum
#  |          trigger (:enum:`Trigger`): IMMEDIATE or STOP enum
#  |          order (:enum:`Order`): MARKET or LIMIT
#  |          time_in_force (:enum:`TIME_IN_FORCE`): GFD or GTC (day or until cancelled)
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  place_sell_order(self, instrument, quantity, bid_price=0.0)
#  |      Wrapper for placing sell orders
#  |
#  |      Args:
#  |          instrument (dict): the RH URL and symbol in dict for the instrument to be traded
#  |          quantity (int): quantity of stocks in order
#  |          bid_price (float): price for order (OPTIONAL! If not given, bid_price is automatic.)
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  place_stop_limit_buy_order(self, instrument_URL=None, symbol=None, time_in_force=None, stop_price=None, price=None, quantity=None)
#  |      Wrapper for placing stop limit buy orders
#  |
#  |      Notes:
#  |          If only one of the instrument_URL or symbol are passed as
#  |          arguments the other will be looked up automatically.
#  |
#  |      Args:
#  |          instrument_URL (str): The RH URL of the instrument
#  |          symbol (str): The ticker symbol of the instrument
#  |          time_in_force (str): 'GFD' or 'GTC' (day or until cancelled)
#  |          stop_price (float): The price at which this becomes a limit order
#  |          price (float): The max price you're willing to pay per share
#  |          quantity (int): Number of shares to buy
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  place_stop_limit_sell_order(self, instrument_URL=None, symbol=None, time_in_force=None, price=None, stop_price=None, quantity=None)
#  |      Wrapper for placing stop limit sell orders
#  |
#  |      Notes:
#  |          If only one of the instrument_URL or symbol are passed as
#  |          arguments the other will be looked up automatically.
#  |
#  |      Args:
#  |          instrument_URL (str): The RH URL of the instrument
#  |          symbol (str): The ticker symbol of the instrument
#  |          time_in_force (str): 'GFD' or 'GTC' (day or until cancelled)
#  |          stop_price (float): The price at which this becomes a limit order
#  |          price (float): The max price you're willing to get per share
#  |          quantity (int): Number of shares to sell
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  place_stop_loss_buy_order(self, instrument_URL=None, symbol=None, time_in_force=None, stop_price=None, quantity=None)
#  |      Wrapper for placing stop loss buy orders
#  |
#  |      Notes:
#  |          If only one of the instrument_URL or symbol are passed as
#  |          arguments the other will be looked up automatically.
#  |
#  |      Args:
#  |          instrument_URL (str): The RH URL of the instrument
#  |          symbol (str): The ticker symbol of the instrument
#  |          time_in_force (str): 'GFD' or 'GTC' (day or until cancelled)
#  |          stop_price (float): The price at which this becomes a market order
#  |          quantity (int): Number of shares to buy
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  place_stop_loss_sell_order(self, instrument_URL=None, symbol=None, time_in_force=None, stop_price=None, quantity=None)
#  |      Wrapper for placing stop loss sell orders
#  |
#  |      Notes:
#  |          If only one of the instrument_URL or symbol are passed as
#  |          arguments the other will be looked up automatically.
#  |
#  |      Args:
#  |          instrument_URL (str): The RH URL of the instrument
#  |          symbol (str): The ticker symbol of the instrument
#  |          time_in_force (str): 'GFD' or 'GTC' (day or until cancelled)
#  |          stop_price (float): The price at which this becomes a market order
#  |          quantity (int): Number of shares to sell
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  portfolios(self)
#  |      Returns the user's portfolio data
#  |
#  |  positions(self)
#  |      Returns the user's positions data
#  |
#  |      Returns:
#  |          (:object: `dict`): JSON dict from getting positions
#  |
#  |  previous_close(self, stock='')
#  |      Get previous closing price for a stock
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (float): previous closing price
#  |
#  |  previous_close_date(self, stock='')
#  |      Get previous closing date for a stock
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (str): previous close date
#  |
#  |  print_quote(self, stock='')
#  |      Print quote information
#  |      Args:
#  |          stock (str): ticker to fetch
#  |
#  |      Returns:
#  |          None
#  |
#  |  print_quotes(self, stocks)
#  |      Print a collection of stocks
#  |
#  |      Args:
#  |          stocks (:obj:`list`): list of stocks to pirnt
#  |
#  |      Returns:
#  |          None
#  |
#  |  quote_data(self, stock='')
#  |      Fetch stock quote
#  |
#  |      Args:
#  |          stock (str or dict): stock ticker symbol or stock instrument
#  |
#  |      Returns:
#  |          (:obj:`dict`): JSON contents from `quotes` endpoint
#  |
#  |  quotes_data(self, stocks)
#  |      Fetch quote for multiple stocks, in one single Robinhood API call
#  |
#  |      Args:
#  |          stocks (list<str>): stock tickers
#  |
#  |      Returns:
#  |          (:obj:`list` of :obj:`dict`): List of JSON contents from `quotes` endpoint, in the
#  |              same order of input args. If any ticker is invalid, a None will occur at that position.
#  |
#  |  securities_owned(self)
#  |      Returns list of securities' symbols that the user has shares in
#  |
#  |      Returns:
#  |          (:object: `dict`): Non-zero positions
#  |
#  |  security_tick(self, instrument)
#  |      Returns ticker of given instrument
#  |
#  |  submit_buy_order(self, instrument_URL=None, symbol=None, order_type=None, time_in_force=None, trigger=None, price=None, stop_price=None, quantity=None, side=None)
#  |      Submits buy order to Robinhood
#  |
#  |
#  |      Notes:
#  |          This is normally not called directly.  Most programs should use
#  |          one of the following instead:
#  |
#  |              place_market_buy_order()
#  |              place_limit_buy_order()
#  |              place_stop_loss_buy_order()
#  |              place_stop_limit_buy_order()
#  |              place_market_sell_order()
#  |              place_limit_sell_order()
#  |              place_stop_loss_sell_order()
#  |              place_stop_limit_sell_order()
#  |
#  |      Args:
#  |          instrument_URL (str): the RH URL for the instrument
#  |          symbol (str): the ticker symbol for the instrument
#  |          order_type (str): 'market' or 'limit'
#  |          time_in_force (:enum:`TIME_IN_FORCE`): 'gfd' or 'gtc' (day or
#  |                                                 until cancelled)
#  |          trigger (str): 'immediate' or 'stop' enum
#  |          price (float): The share price you'll accept
#  |          stop_price (float): The price at which the order becomes a
#  |                              market or limit order
#  |          quantity (int): The number of shares to buy/sell
#  |          side (str): BUY or sell
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  submit_sell_order(self, instrument_URL=None, symbol=None, order_type=None, time_in_force=None, trigger=None, price=None, stop_price=None, quantity=None, side=None)
#  |      Submits order to Robinhood
#  |
#  |      Notes:
#  |          This is normally not called directly.  Most programs should use
#  |          one of the following instead:
#  |
#  |              place_market_buy_order()
#  |              place_limit_buy_order()
#  |              place_stop_loss_buy_order()
#  |              place_stop_limit_buy_order()
#  |              place_market_sell_order()
#  |              place_limit_sell_order()
#  |              place_stop_loss_sell_order()
#  |              place_stop_limit_sell_order()
#  |
#  |      Args:
#  |          instrument_URL (str): the RH URL for the instrument
#  |          symbol (str): the ticker symbol for the instrument
#  |          order_type (str): 'MARKET' or 'LIMIT'
#  |          time_in_force (:enum:`TIME_IN_FORCE`): GFD or GTC (day or
#  |                                                 until cancelled)
#  |          trigger (str): IMMEDIATE or STOP enum
#  |          price (float): The share price you'll accept
#  |          stop_price (float): The price at which the order becomes a
#  |                              market or limit order
#  |          quantity (int): The number of shares to buy/sell
#  |          side (str): BUY or sell
#  |
#  |      Returns:
#  |          (:obj:`requests.request`): result from `orders` put command
#  |
#  |  symbol(self, stock='')
#  |      Get symbol for a stock
#  |
#  |      Note:
#  |          queries `quote` endpoint, dict wrapper
#  |
#  |      Args:
#  |          stock (str): stock ticker
#  |
#  |      Returns:
#  |          (str): stock symbol
#  |
#  |  watchlists(self)
#  |      Returns list of securities' symbols that the user has in watchlist
#  |      Returns:
#  |          (:object: `dict`): Non-zero positions
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  auth_token = None
#  |
#  |  client_id = 'c82SH0WZOsabOXGP2sxqcj34FxkvfnWRZBKlBjFS'
#  |
#  |  headers = None
#  |
#  |  logger = <Logger Robinhood (WARNING)>
#  |
#  |  password = None
#  |
#  |  refresh_token = None
#  |
#  |  session = None
#  |
#  |  username = None

# %%
#define URL for scraping
theurl = 'http://citizenatlas.dc.gov/newwebservices/locationverifier.asmx/findLocation?str=1050+1ST+STREET+NE'
thepage = urllib.request.urlopen(theurl)

# %%
#Cooking the Soup
soup = BeautifulSoup(thepage,"html.parser")

# %%
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <returnobject xmlns="http://tempuri.org/newWebServices/LocationVerifier" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
# <details>&lt;STRONG&gt;Normalized:&lt;/STRONG&gt; 1050 1ST STREET NE&lt;/br&gt;</details>
# <returndataset>
# <xs:schema id="NewDataSet" xmlns="" xmlns:msdata="urn:schemas-microsoft-com:xml-msdata" xmlns:xs="http://www.w3.org/2001/XMLSchema">
# <xs:element msdata:isdataset="true" msdata:usecurrentlocale="true" name="NewDataSet">
# <xs:complextype>
# <xs:choice maxoccurs="unbounded" minoccurs="0">
# <xs:element name="Table1">
# <xs:complextype>
# <xs:sequence>
# <xs:element minoccurs="0" name="ADDRESS_ID" type="xs:int"></xs:element>
# <xs:element minoccurs="0" name="MARID" type="xs:int"></xs:element>
# <xs:element minoccurs="0" name="STATUS" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="FULLADDRESS" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="ADDRNUM" type="xs:int"></xs:element>
# <xs:element minoccurs="0" name="ADDRNUMSUFFIX" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="STNAME" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="STREET_TYPE" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="QUADRANT" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="CITY" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="STATE" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="XCOORD" type="xs:decimal"></xs:element>
# <xs:element minoccurs="0" name="YCOORD" type="xs:decimal"></xs:element>
# <xs:element minoccurs="0" name="SSL" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="ANC" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="PSA" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="WARD" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="NBHD_ACTION" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="CLUSTER_" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="POLDIST" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="ROC" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="CENSUS_TRACT" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="VOTE_PRCNCT" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="SMD" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="ZIPCODE" type="xs:int"></xs:element>
# <xs:element minoccurs="0" name="NATIONALGRID" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="ROADWAYSEGID" type="xs:int"></xs:element>
# <xs:element minoccurs="0" name="FOCUS_IMPROVEMENT_AREA" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="HAS_ALIAS" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="HAS_CONDO_UNIT" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="HAS_RES_UNIT" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="HAS_SSL" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="LATITUDE" type="xs:decimal"></xs:element>
# <xs:element minoccurs="0" name="LONGITUDE" type="xs:decimal"></xs:element>
# <xs:element minoccurs="0" name="STREETVIEWURL" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="RES_TYPE" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="WARD_2002" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="WARD_2012" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="ANC_2002" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="ANC_2012" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="SMD_2002" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="SMD_2012" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="IMAGEURL" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="IMAGEDIR" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="IMAGENAME" type="xs:string"></xs:element>
# <xs:element minoccurs="0" name="ConfidenceLevel" type="xs:double"></xs:element>
# </xs:sequence>
# </xs:complextype>
# </xs:element>
# </xs:choice>
# </xs:complextype>
# </xs:element>
# </xs:schema>
# <diffgr:diffgram xmlns:diffgr="urn:schemas-microsoft-com:xml-diffgram-v1" xmlns:msdata="urn:schemas-microsoft-com:xml-msdata">
# <newdataset xmlns="">
# <table1 diffgr:id="Table11" msdata:roworder="0">
# <address_id>310029</address_id>
# <marid>310029</marid>
# <status>ACTIVE</status>
# <fulladdress>1050 1ST STREET NE</fulladdress>
# <addrnum>1050</addrnum>
# <stname>1ST</stname>
# <street_type>STREET</street_type>
# <quadrant>NE</quadrant>
# <city>WASHINGTON</city>
# <state>DC</state>
# <xcoord>399460.41</xcoord>
# <ycoord>137286.59</ycoord>
# <ssl>0674    0854</ssl>
# <anc>ANC 6C</anc>
# <psa>Police Service Area 501</psa>
# <ward>Ward 6</ward>
# <nbhd_action xml:space="preserve"> </nbhd_action>
# <cluster_>Cluster 25</cluster_>
# <poldist>Police District - Fifth District</poldist>
# <roc>Police Sector 5D1</roc>
# <census_tract>010600</census_tract>
# <vote_prcnct>Precinct 83</vote_prcnct>
# <smd>SMD 6C06</smd>
# <zipcode>20002</zipcode>
# <nationalgrid>18S UJ 26034 07974</nationalgrid>
# <roadwaysegid>8813</roadwaysegid>
# <focus_improvement_area>NA</focus_improvement_area>
# <has_alias>N</has_alias>
# <has_condo_unit>N</has_condo_unit>
# <has_res_unit>N</has_res_unit>
# <has_ssl>Y</has_ssl>
# <latitude>38.90343495</latitude>
# <longitude>-77.00622080</longitude>
# <res_type>NON RESIDENTIAL</res_type>
# <ward_2002>Ward 6</ward_2002>
# <ward_2012>Ward 6</ward_2012>
# <anc_2002>ANC 6C</anc_2002>
# <anc_2012>ANC 6C</anc_2012>
# <smd_2002>SMD 6C04</smd_2002>
# <smd_2012>SMD 6C06</smd_2012>
# <imageurl>http://citizenatlas.dc.gov/mobilevideo</imageurl>
# <imagedir>NO_IMAGE</imagedir>
# <imagename>No_Image_Available.JPG</imagename>
# <confidencelevel>100</confidencelevel>
# </table1>
# </newdataset>
# </diffgr:diffgram>
# </returndataset>
# <returncddataset>
# <xs:schema id="NewDataSet" xmlns="" xmlns:msdata="urn:schemas-microsoft-com:xml-msdata" xmlns:xs="http://www.w3.org/2001/XMLSchema">
# <xs:element msdata:isdataset="true" msdata:usecurrentlocale="true" name="NewDataSet">
# <xs:complextype>
# <xs:choice maxoccurs="unbounded" minoccurs="0">
# <xs:element name="Address_x0020_Return_x0020_Codes">
# <xs:complextype>
# <xs:sequence>
# <xs:element minoccurs="0" msdata:readonly="true" name="Component" type="xs:string"></xs:element>
# <xs:element minoccurs="0" msdata:readonly="true" name="Parsed_x0020__x0026__x0020_Normalized" type="xs:string"></xs:element>
# <xs:element minoccurs="0" msdata:readonly="true" name="Assessment" type="xs:string"></xs:element>
# </xs:sequence>
# </xs:complextype>
# </xs:element>
# </xs:choice>
# </xs:complextype>
# </xs:element>
# </xs:schema>
# <diffgr:diffgram xmlns:diffgr="urn:schemas-microsoft-com:xml-diffgram-v1" xmlns:msdata="urn:schemas-microsoft-com:xml-msdata">
# <newdataset xmlns="">
# <address_x0020_return_x0020_codes diffgr:haschanges="inserted" diffgr:id="Address Return Codes1" msdata:roworder="0">
# <component>Full Address</component>
# <parsed_x0020__x0026__x0020_normalized>1050 1ST STREET NE</parsed_x0020__x0026__x0020_normalized>
# <assessment>Verified</assessment>
# </address_x0020_return_x0020_codes>
# </newdataset>
# </diffgr:diffgram>
# </returncddataset>
# <sourceoperation>DC Address</sourceoperation>
# <processtime>0 seconds and 0 milliseconds</processtime>
# </returnobject>

# %%
place = soup.text

# %%
place
# Out:
# '\n\n<STRONG>Normalized:</STRONG> 1050 1ST STREET NE</br>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n310029\n310029\nACTIVE\n1050 1ST STREET NE\n1050\n1ST\nSTREET\nNE\nWASHINGTON\nDC\n399460.41\n137286.59\n0674    0854\nANC 6C\nPolice Service Area 501\nWard 6\n \nCluster 25\nPolice District - Fifth District\nPolice Sector 5D1\n010600\nPrecinct 83\nSMD 6C06\n20002\n18S UJ 26034 07974\n8813\nNA\nN\nN\nN\nY\n38.90343495\n-77.00622080\nNON RESIDENTIAL\nWard 6\nWard 6\nANC 6C\nANC 6C\nSMD 6C04\nSMD 6C06\nhttp://citizenatlas.dc.gov/mobilevideo\nNO_IMAGE\nNo_Image_Available.JPG\n100\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFull Address\n1050 1ST STREET NE\nVerified\n\n\n\n\nDC Address\n0 seconds and 0 milliseconds\n'

# %%
for word in place:
    print(word)
# Out:
# <
# S
# T
# R
# O
# N
# G
# >
# N
# o
# r
# m
# a
# l
# i
# z
# e
# d
# :
# <
# /
# S
# T
# R
# O
# N
# G
# >
#
# 1
# 0
# 5
# 0
#
# 1
# S
# T
#
# S
# T
# R
# E
# E
# T
#
# N
# E
# <
# /
# b
# r
# >
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3
# 1
# 0
# 0
# 2
# 9
#
#
# 3
# 1
# 0
# 0
# 2
# 9
#
#
# A
# C
# T
# I
# V
# E
#
#
# 1
# 0
# 5
# 0
#
# 1
# S
# T
#
# S
# T
# R
# E
# E
# T
#
# N
# E
#
#
# 1
# 0
# 5
# 0
#
#
# 1
# S
# T
#
#
# S
# T
# R
# E
# E
# T
#
#
# N
# E
#
#
# W
# A
# S
# H
# I
# N
# G
# T
# O
# N
#
#
# D
# C
#
#
# 3
# 9
# 9
# 4
# 6
# 0
# .
# 4
# 1
#
#
# 1
# 3
# 7
# 2
# 8
# 6
# .
# 5
# 9
#
#
# 0
# 6
# 7
# 4
#
#
#
#
# 0
# 8
# 5
# 4
#
#
# A
# N
# C
#
# 6
# C
#
#
# P
# o
# l
# i
# c
# e
#
# S
# e
# r
# v
# i
# c
# e
#
# A
# r
# e
# a
#
# 5
# 0
# 1
#
#
# W
# a
# r
# d
#
# 6
#
#
#
#
#
# C
# l
# u
# s
# t
# e
# r
#
# 2
# 5
#
#
# P
# o
# l
# i
# c
# e
#
# D
# i
# s
# t
# r
# i
# c
# t
#
# -
#
# F
# i
# f
# t
# h
#
# D
# i
# s
# t
# r
# i
# c
# t
#
#
# P
# o
# l
# i
# c
# e
#
# S
# e
# c
# t
# o
# r
#
# 5
# D
# 1
#
#
# 0
# 1
# 0
# 6
# 0
# 0
#
#
# P
# r
# e
# c
# i
# n
# c
# t
#
# 8
# 3
#
#
# S
# M
# D
#
# 6
# C
# 0
# 6
#
#
# 2
# 0
# 0
# 0
# 2
#
#
# 1
# 8
# S
#
# U
# J
#
# 2
# 6
# 0
# 3
# 4
#
# 0
# 7
# 9
# 7
# 4
#
#
# 8
# 8
# 1
# 3
#
#
# N
# A
#
#
# N
#
#
# N
#
#
# N
#
#
# Y
#
#
# 3
# 8
# .
# 9
# 0
# 3
# 4
# 3
# 4
# 9
# 5
#
#
# -
# 7
# 7
# .
# 0
# 0
# 6
# 2
# 2
# 0
# 8
# 0
#
#
# N
# O
# N
#
# R
# E
# S
# I
# D
# E
# N
# T
# I
# A
# L
#
#
# W
# a
# r
# d
#
# 6
#
#
# W
# a
# r
# d
#
# 6
#
#
# A
# N
# C
#
# 6
# C
#
#
# A
# N
# C
#
# 6
# C
#
#
# S
# M
# D
#
# 6
# C
# 0
# 4
#
#
# S
# M
# D
#
# 6
# C
# 0
# 6
#
#
# h
# t
# t
# p
# :
# /
# /
# c
# i
# t
# i
# z
# e
# n
# a
# t
# l
# a
# s
# .
# d
# c
# .
# g
# o
# v
# /
# m
# o
# b
# i
# l
# e
# v
# i
# d
# e
# o
#
#
# N
# O
# _
# I
# M
# A
# G
# E
#
#
# N
# o
# _
# I
# m
# a
# g
# e
# _
# A
# v
# a
# i
# l
# a
# b
# l
# e
# .
# J
# P
# G
#
#
# 1
# 0
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# F
# u
# l
# l
#
# A
# d
# d
# r
# e
# s
# s
#
#
# 1
# 0
# 5
# 0
#
# 1
# S
# T
#
# S
# T
# R
# E
# E
# T
#
# N
# E
#
#
# V
# e
# r
# i
# f
# i
# e
# d
#
#
#
#
#
#
#
#
#
#
# D
# C
#
# A
# d
# d
# r
# e
# s
# s
#
#
# 0
#
# s
# e
# c
# o
# n
# d
# s
#
# a
# n
# d
#
# 0
#
# m
# i
# l
# l
# i
# s
# e
# c
# o
# n
# d
# s

# %% [markdown]
# KEVIN is a headache
